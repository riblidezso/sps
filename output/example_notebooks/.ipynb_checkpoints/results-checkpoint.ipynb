# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')

# %%
data=pd.read_csv('../mcmc_points.dat',sep='\t').iloc[:,:-1]

# %%
dump=data.plot(subplots=True,figsize=(9,20))

# %%
dump=scatter_matrix(data.iloc[1000:,:], alpha=0.2, figsize=(9, 9), diagonal='hist')

# %%
best_fit=pd.read_csv('../best_fit.tsv',sep='\t',header=None)
measurement=pd.read_csv('../../input/testspec1.csv',sep=',')

plt.figure(figsize=(12,9))
plt.plot(measurement['# Spectral_Value'],measurement['Flux_Value'],label='measurement')
plt.plot(measurement['# Spectral_Value'],best_fit[1],label='fitted specrum')
plt.plot(measurement['# Spectral_Value'],measurement['Flux_Value']-best_fit[1],label='error')
plt.legend()
